# %% [markdown]
# # Titanic Survivie Analysis

# %%
# import libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# read the data set
df=pd.read_csv('train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# let's display last 5 samples
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
#let' know how many columns and rows are available 
print('number of rows are :',df.shape[0])
print('number of columns are :',df.shape[1])
# Out:
# number of rows are : 891
# number of columns are : 12

# %%
# let's know what are the datatypes of each column and it's information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# let's get the overall statistics of data set
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
# Data filtering  is work on rows on some condition
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df[['Name','Age']]
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]

# %%
# let's check how many males are present 
sum(df['Sex']=='male')
# Out:
# 577

# %%
# to display them 
df[df['Sex']=='male'].head()
# Out:
#    PassengerId  Survived  Pclass                            Name   Sex   Age  \
# 0            1         0       3         Braund, Mr. Owen Harris  male  22.0
# 4            5         0       3        Allen, Mr. William Henry  male  35.0
# 5            6         0       3                Moran, Mr. James  male   NaN
# 6            7         0       1         McCarthy, Mr. Timothy J  male  54.0
# 7            8         0       3  Palsson, Master. Gosta Leonard  male   2.0
#
#    SibSp  Parch     Ticket     Fare Cabin Embarked
# 0      1      0  A/5 21171   7.2500   NaN        S
# 4      0      0     373450   8.0500   NaN        S
# 5      0      0     330877   8.4583   NaN        Q
# 6      0      0      17463  51.8625   E46        S
# 7      3      1     349909  21.0750   NaN        S

# %%
# let's know how many people are survived
sum(df['Survived']==1)
# Out:
# 342

# %%
# to display them 
df[df['Survived']==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Check how many male and female people are survived
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
sum(df['Survived']==(df['Sex']=='male'))
# Out:
# 190

# %%
import seaborn as sns

# %%
sns.countplot(x='Survived',data=df)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
# Let' Check the null values in the data set
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# As you observe the above total number of rows is 891 and age column has 177 null values and Cabin column had 687 column

# %%
data_missing=df.isnull().sum()*100/len(df)
data_missing
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %% [markdown]
# here Cabin has 77% of data missing, Age has 19% of data missing and Embarked column has 0.2%

# %%
# let's Drop the Cabin column 
df=df.drop('Cabin',axis=1)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
# Handling Missiong Values
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df['Embarked'].mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
# fill the missing values with mode value
df['Embarked'].fillna('S',inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# dtype: int64

# %%
# Let' Handle age column 
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
df['Age']=df['Age'].fillna(df['Age'].mean())

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %% [markdown]
# As you observe the data in Sex column it is categorical

# %%
df['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df['gender']=df['Sex'].map({'male':1,'female':0})

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked  gender
# 0      0         A/5 21171   7.2500        S       1
# 1      0          PC 17599  71.2833        C       0
# 2      0  STON/O2. 3101282   7.9250        S       0
# 3      0            113803  53.1000        S       0
# ...

# %%
x=df['Sex'].map({'male':1,'female':0})
x.head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    0
# 4    1
# Name: Sex, dtype: int64

# %%
# Newly added column is added at last but if you want to add it at particular index you should insert 
df.insert(5,'gender_new',x)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  gender_new  \
# 0                            Braund, Mr. Owen Harris    male           1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female           0
# 2                             Heikkinen, Miss. Laina  female           0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female           0
# 4                           Allen, Mr. William Henry    male           1
#
#     Age  SibSp  Parch            Ticket     Fare Embarked  gender
# 0  22.0      1      0         A/5 21171   7.2500        S       1
# 1  38.0      1      0          PC 17599  71.2833        C       0
# 2  26.0      0      0  STON/O2. 3101282   7.9250        S       0
# ...

# %%
# As you observe there is another categorical encoding which is Embarked
df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
df=pd.get_dummies(df,columns=['Embarked'])

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  gender_new  \
# 0                            Braund, Mr. Owen Harris    male           1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female           0
# 2                             Heikkinen, Miss. Laina  female           0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female           0
# 4                           Allen, Mr. William Henry    male           1
#
#     Age  SibSp  Parch            Ticket     Fare  gender  Embarked_C  \
# 0  22.0      1      0         A/5 21171   7.2500       1       False
# 1  38.0      1      0          PC 17599  71.2833       0        True
# 2  26.0      0      0  STON/O2. 3101282   7.9250       0       False
# ...

# %%
# in above we got True or Flase let map them 
df=df.replace({'True':1,'False':0})

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  gender_new  \
# 0                            Braund, Mr. Owen Harris    male           1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female           0
# 2                             Heikkinen, Miss. Laina  female           0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female           0
# 4                           Allen, Mr. William Henry    male           1
#
#     Age  SibSp  Parch            Ticket     Fare  gender  Embarked_C  \
# 0  22.0      1      0         A/5 21171   7.2500       1       False
# 1  38.0      1      0          PC 17599  71.2833       0        True
# 2  26.0      0      0  STON/O2. 3101282   7.9250       0       False
# ...

# %% [markdown]
# # UNIVARIENT ANALYSIS

# %%
# let's check the how many people are survived and deaths
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'gender_new', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'gender', 'Embarked_C',
#        'Embarked_Q', 'Embarked_S'],
#       dtype='object')

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
sns.countplot(x='Survived',data=df)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
# How many peoples are first and second class and third class
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
sns.countplot(x='Pclass',data=df)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(x='gender',data=df)
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
plt.hist(df['Age'])
# Out:
# (array([ 54.,  46., 177., 346., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
sns.boxplot(x='Age',data=df,orient='h')
# Out:
# <Axes: xlabel='Age'>

# %% [markdown]
# # BIVARIENT ANALYSIS

# %%
# Let's chech who has better survive rate male or female

# %%
sns.barplot(x='Survived',y='gender',data=df)
# Out:
# <Axes: xlabel='Survived', ylabel='gender'>

# %%
# which class have better survive rate
sns.barplot(x='Pclass',y='Survived',data=df)
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %% [markdown]
# # Feature Engineering

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'gender_new', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'gender', 'Embarked_C',
#        'Embarked_Q', 'Embarked_S'],
#       dtype='object')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  gender_new  \
# 0                            Braund, Mr. Owen Harris    male           1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female           0
# 2                             Heikkinen, Miss. Laina  female           0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female           0
# 4                           Allen, Mr. William Henry    male           1
#
#     Age  SibSp  Parch            Ticket     Fare  gender  Embarked_C  \
# 0  22.0      1      0         A/5 21171   7.2500       1       False
# 1  38.0      1      0          PC 17599  71.2833       0        True
# 2  26.0      0      0  STON/O2. 3101282   7.9250       0       False
# ...

# %% [markdown]
# In above dataset SibSp means Sibling and Spouses, Parch means Parent and childern : combination of those both gives family

# %%
df['family']=df['SibSp']+df['Parch']
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  gender_new  \
# 0                            Braund, Mr. Owen Harris    male           1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female           0
# 2                             Heikkinen, Miss. Laina  female           0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female           0
# 4                           Allen, Mr. William Henry    male           1
#
#     Age  SibSp  Parch            Ticket     Fare  gender  Embarked_C  \
# 0  22.0      1      0         A/5 21171   7.2500       1       False
# 1  38.0      1      0          PC 17599  71.2833       0        True
# 2  26.0      0      0  STON/O2. 3101282   7.9250       0       False
# ...

# %%
# let's findout the fare person
df['fare_per_person']=df['Fare']/(df['family']+1)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  gender_new  \
# 0                            Braund, Mr. Owen Harris    male           1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female           0
# 2                             Heikkinen, Miss. Laina  female           0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female           0
# 4                           Allen, Mr. William Henry    male           1
#
#     Age  SibSp  Parch            Ticket     Fare  gender  Embarked_C  \
# 0  22.0      1      0         A/5 21171   7.2500       1       False
# 1  38.0      1      0          PC 17599  71.2833       0        True
# 2  26.0      0      0  STON/O2. 3101282   7.9250       0       False
# ...
